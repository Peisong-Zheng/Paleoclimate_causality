# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np

# Set up the figure and axis
fig = plt.figure(figsize=(10, 8), dpi=900)
ax = plt.axes(projection=ccrs.Orthographic(central_longitude=-80, central_latitude=0))

# Draw the coastlines and land
ax.coastlines(linewidth=4)
# ax.stock_img()

# Plot the latitude and longitude lines
# gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)
# gl.top_labels = False
# gl.right_labels = False

# Simulate the tilt by adding lines and annotations
# Annotations for angles and paths
# ax.text(0, 0, 'Low angle has longer path', transform=ccrs.Geodetic(), fontsize=12, color='white', ha='center', bbox=dict(facecolor='black', alpha=0.5))
# ax.text(0, 0, 'High angle has short path', transform=ccrs.Geodetic(), fontsize=12, color='white', ha='center', bbox=dict(facecolor='black', alpha=0.5))
# ax.text(0, 0, 'Sun\'s rays', transform=ccrs.Geodetic(), fontsize=12, color='white', ha='center', bbox=dict(facecolor='black', alpha=0.5))

# # Adding equator, tropics, and arctic/antarctic circles
# ax.plot([-180, 180], [0, 0], color='white', linewidth=1.5, transform=ccrs.Geodetic())
# ax.plot([-180, 180], [23.5, 23.5], color='white', linestyle='--', linewidth=1.5, transform=ccrs.Geodetic())
# ax.plot([-180, 180], [-23.5, -23.5], color='white', linestyle='--', linewidth=1.5, transform=ccrs.Geodetic())
# ax.plot([-180, 180], [66.5, 66.5], color='white', linestyle='--', linewidth=1.5, transform=ccrs.Geodetic())
# ax.plot([-180, 180], [-66.5, -66.5], color='white', linestyle='--', linewidth=1.5, transform=ccrs.Geodetic())

# # Annotating the tropics and circles
# ax.text(0, 23.5, '23.5°N', transform=ccrs.Geodetic(), fontsize=10, color='white')
# ax.text(0, -23.5, '23.5°S', transform=ccrs.Geodetic(), fontsize=10, color='white')
# ax.text(0, 66.5, '66.5°N', transform=ccrs.Geodetic(), fontsize=10, color='white')
# ax.text(0, -66.5, '66.5°S', transform=ccrs.Geodetic(), fontsize=10, color='white')

# Draw the sunlight angle
# ax.annotate('', xy=(0.9, 0.5), xycoords='axes fraction', xytext=(0.6, 0.5),
#             arrowprops=dict(facecolor='yellow', edgecolor='yellow', shrink=0.05))

# plt.title('Tilted Globe with Sunlight Paths')
plt.show()
